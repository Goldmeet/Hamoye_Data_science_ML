# %% [markdown]
# <a href="https://colab.research.google.com/github/Goldmeet/Hamoye_Data_science_ML/blob/main/Machine_Learning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
Energy_df = pd.read_csv('energydata_complete.csv')

# %%
Energy_df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %% [markdown]
# **SUMMARY OF THE DATA SET**

# %%
Energy_df.describe(include=[np.number])
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %% [markdown]
# **CHECKING FOR NORMALITY**

# %%
sm.qqplot(Energy_df['Appliances'] )

# %%
show = sns.histplot(data = Energy_df['Appliances'], binwidth= 30, stat = 'probability', kde = True, common_norm = True)
show
# Out:
# <Axes: xlabel='Appliances', ylabel='Probability'>

# %%
Energy_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
Energy_df.isna().count(axis = 0)
# Out:
# date           19735
# Appliances     19735
# lights         19735
# T1             19735
# RH_1           19735
# T2             19735
# RH_2           19735
# T3             19735
# RH_3           19735
# T4             19735
# RH_4           19735
# T5             19735
# RH_5           19735
# T6             19735
# RH_6           19735
# T7             19735
# RH_7           19735
# T8             19735
# RH_8           19735
# T9             19735
# RH_9           19735
# T_out          19735
# Press_mm_hg    19735
# RH_out         19735
# Windspeed      19735
# Visibility     19735
# Tdewpoint      19735
# rv1            19735
# rv2            19735
# dtype: int64

# %%
sns.regplot(x='T2', y='T6', data= Energy_df)
# Out:
# <Axes: xlabel='T2', ylabel='T6'>

# %%
Energy_df2 = Energy_df.drop(['date', 'lights'], axis=1)

# %%
Energy_df2
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
sc = MinMaxScaler()
Norm_Energy = pd.DataFrame(sc.fit_transform(Energy_df2), columns= Energy_df2.columns)

# %%
Norm_Energy
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
Norm_Energy = Norm_Energy.dropna(axis = 0)

# %%
Norm_Energy
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
sns.histplot(Norm_Energy['Appliances'], stat = 'probability', kde = True)
# Out:
# <Axes: xlabel='Appliances', ylabel='Probability'>

# %%
T_Sample = Norm_Energy.loc[:, ['T6','T2']]
T_Sample
# Out:
#              T6        T2
# 0      0.381070  0.225345
# 1      0.375443  0.225345
# 2      0.367487  0.225345
# 3      0.363800  0.225345
# 4      0.361859  0.225345
# ...         ...       ...
# 19730  0.898317  0.711655
# 19731  0.880852  0.701769
# 19732  0.864260  0.692651
# 19733  0.829525  0.677054
# 19734  0.788580  0.666171
#
# [19735 rows x 2 columns]

# %%
x_2 = T_Sample['T2']
y_2 = T_Sample['T6']

# %% [markdown]
# **ASSIGNING  X'S VALUES AND THE Y VALUE**

# %%
X = Norm_Energy.drop('Appliances', axis = 1)
y = Norm_Energy['Appliances']

# %% [markdown]
# **SPLITTING OF THE DATA SET INTO TRAIN SET AND TEST SET**

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state=42)

# %% [markdown]
# **FITTING THE REGRESSION MODEL**

# %%
model = LinearRegression()
fit = model.fit(X_train, y_train)
pred_val = model.predict(X_train)
pred_val_test = model.predict(X_test)

# %% [markdown]
# **COEFFICIENT OF THE LINEAR MODEL**

# %%
df_ = pd.Series(fit.coef_, index = X.columns)
fit.intercept_
df_
# Out:
# T1            -0.003281
# RH_1           0.553547
# T2            -0.236178
# RH_2          -0.456698
# T3             0.290627
# RH_3           0.096048
# T4             0.028981
# RH_4           0.026386
# T5            -0.015657
# RH_5           0.016006
# T6             0.236425
# RH_6           0.038049
# T7             0.010319
# RH_7          -0.044614
# T8             0.101995
# RH_8          -0.157595
# T9            -0.189941
# RH_9          -0.039800
# T_out         -0.321860
# Press_mm_hg    0.006839
# RH_out        -0.077671
# Windspeed      0.029183
# Visibility     0.012307
# Tdewpoint      0.117758
# rv1            0.000770
# rv2            0.000770
# dtype: float64

# %% [markdown]
# **PREDICTED VALUES OF THE TRAIN SET**

# %%
pred_val
# Out:
# array([0.03736239, 0.08440778, 0.02815806, ..., 0.04623579, 0.08713294,
#        0.07302946])

# %% [markdown]
# **CHECKING THE PERFORMANCE OF THE MODEL**

# %%
mean_abs_er = mean_absolute_error(y_train, pred_val)
mean_abs_er_test = mean_absolute_error(y_test,pred_val_test)

# %%
Mean_error = [mean_abs_er.round(3), mean_abs_er_test.round(3)]
Mean_error
# Out:
# [0.05, 0.05]

# %%
square_error = np.sqrt(mean_squared_error(y_train,pred_val))
square_error_test = np.sqrt(mean_squared_error(y_test, pred_val_test))

# %%
Sqrt_residual = [square_error.round(3), square_error_test.round(3)]
Sqrt_residual
# Out:
# [0.089, 0.088]

# %% [markdown]
# **REGULARIZATION**

# %%
rid_reg = Ridge(alpha = 0.5)
rid_reg.fit(X_train, y_train)
rid_df  = pd.Series(rid_reg.coef_, index = X.columns)

las_reg = Lasso(alpha = 0.001)
las_reg.fit(X_train, y_train)
la_df = pd.Series(las_reg.coef_, index = X.columns)

la_df, rid_df
# Out:
# (T1             0.000000
#  RH_1           0.017880
#  T2             0.000000
#  RH_2          -0.000000
#  T3             0.000000
#  RH_3           0.000000
#  T4            -0.000000
#  RH_4           0.000000
#  T5            -0.000000
#  RH_5           0.000000
#  T6             0.000000
#  RH_6          -0.000000
#  T7            -0.000000
#  RH_7          -0.000000
#  T8             0.000000
#  RH_8          -0.000110
#  T9            -0.000000
#  RH_9          -0.000000
#  T_out          0.000000
#  Press_mm_hg   -0.000000
#  RH_out        -0.049557
#  Windspeed      0.002912
#  Visibility     0.000000
#  Tdewpoint      0.000000
#  rv1           -0.000000
#  rv2           -0.000000
#  dtype: float64,
#  T1            -0.021549
#  RH_1           0.511932
#  T2            -0.193880
#  RH_2          -0.401134
#  T3             0.287408
#  RH_3           0.094976
#  T4             0.027006
#  RH_4           0.024168
#  T5            -0.020727
#  RH_5           0.016176
# ...
